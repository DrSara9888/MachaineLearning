# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import numpy as np
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
digits = load_digits()

# %%
from sklearn.model_selection import train_test_split
X_train, y_train, X_test, y_test = train_test_split(digits.data, digits.target, test_size=0.3)

# %%
svm =SVC(gamma='auto')
svm.fit(X_train, y_train)
svm.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9e85ed6a156c> in <module>
#       1 svm =SVC(gamma='auto')
# ----> 2 svm.fit(X_train, y_train)
#       3 svm.score(X_test, y_test)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     758                         dtype=None)
# ...

# %%
rf = RandomForestClassifier(n_estimators=40)

# %%
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-1721cca571e2> in <module>
# ----> 1 rf.fit(X_train, y_train)
#       2 rf.score(X_test, y_test)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# /usr/local/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# ...

# %%
def get_score(modle, X_train, y_train, X_test, y_test ):
    modle.fit(X_train,y_train)
    return modle.score(X_test,y_test)
    
get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7a3b8c86385a> in <module>
#       3     return modle.score(X_test,y_test)
#       4
# ----> 5 get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
#
# <ipython-input-20-7a3b8c86385a> in get_score(modle, X_train, y_train, X_test, y_test)
#       1 def get_score(modle, X_train, y_train, X_test, y_test ):
# ----> 2     modle.fit(X_train,y_train)
#       3     return modle.score(X_test,y_test)
#       4
#       5 get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1525
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1527                          accept_large_sparse=solver != 'liblinear')
# ...

# %%
get_score(RandomForestClassifier(), X_train,X_test,y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5ba790c5a07b> in <module>
# ----> 1 get_score(RandomForestClassifier(), X_train,X_test,y_train,y_test)
#
# <ipython-input-20-7a3b8c86385a> in get_score(modle, X_train, y_train, X_test, y_test)
#       1 def get_score(modle, X_train, y_train, X_test, y_test ):
# ----> 2     modle.fit(X_train,y_train)
#       3     return modle.score(X_test,y_test)
#       4
#       5 get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# ...

# %%
get_score(SVC(),X_train,X_test,y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-5faaf4eabddf> in <module>
# ----> 1 get_score(SVC(),X_train,X_test,y_train,y_test)
#
# <ipython-input-7-7a3b8c86385a> in get_score(modle, X_train, y_train, X_test, y_test)
#       1 def get_score(modle, X_train, y_train, X_test, y_test ):
# ----> 2     modle.fit(X_train,y_train)
#       3     return modle.score(X_test,y_test)
#       4
#       5 get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     146         X, y = check_X_y(X, y, dtype=np.float64,
#     147                          order='C', accept_sparse='csr',
# --> 148                          accept_large_sparse=False)
#     149         y = self._validate_targets(y)
#     150
#
# ...

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=3)
kf
# Out:
# KFold(n_splits=3, random_state=None, shuffle=False)

# %%
for train_index, test_index in kf.split([1,2,3,4,5,6,7,8,9]):
    print (test_index,train_index)
# Out:
# [0 1 2] [3 4 5 6 7 8]
# [3 4 5] [0 1 2 6 7 8]
# [6 7 8] [0 1 2 3 4 5]

# %%
from sklearn.model_selection import StratifiedKFold 
folds =StratifiedKFold(n_splits=3)

scores_logistic=[]
scores_svm=[]
scores_rf=[]

for train_index, test_index in folds.split(digits.data, digits.target):
    X_train, X_test, y_train, y_test = digits.data[train_index], digits.data[test_index], \
                                       digits.target[train_index], digits.target[test_index]
    get_score(LogisticRegression(),X_train,X_test,y_train,y_test)
    get_score(SVC(), X_train, X_test, y_train, y_test)
    get_score(RandomForestClassifier(n_estimators=40), X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0de44ff1ea53> in <module>
#       9     X_train, X_test, y_train, y_test = digits.data[train_index], digits.data[test_index], \
#      10                                        digits.target[train_index], digits.target[test_index]
# ---> 11     get_score(LogisticRegression(),X_train,X_test,y_train,y_test)
#      12     get_score(SVC(), X_train, X_test, y_train, y_test)
#      13     get_score(RandomForestClassifier(n_estimators=40), X_train, X_test, y_train, y_test)
#
# <ipython-input-7-7a3b8c86385a> in get_score(modle, X_train, y_train, X_test, y_test)
#       1 def get_score(modle, X_train, y_train, X_test, y_test ):
# ----> 2     modle.fit(X_train,y_train)
#       3     return modle.score(X_test,y_test)
#       4
#       5 get_score(LogisticRegression(),X_train,X_test, y_train,y_test)
#
# ...
